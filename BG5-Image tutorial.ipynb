# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import data 
import numpy as np

img=data.lena()
imgplot = plt.imshow(img)

# %%
lum_img = img[:,:,0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('spectral')

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f52b963ca28>

# %%
a = plt.hist(lum_img.ravel(), bins=256, range=(0.0, 255.0), fc='k', ec='k')

# %%
imgplot = plt.imshow(lum_img, clim=(0.0, 232))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f52b880a878>

# %%
imgplot = plt.imshow(lum_img, interpolation="bicubic")

# %%
imgplot = plt.imshow(lum_img, interpolation="nearest")
